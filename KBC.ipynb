# %%
title="WELCOME TO KAUN BANEGA CROREPATI" 
print(title.center(80)) 
questions= [ 
  ["1. What is the capital of Australia?","Sydney", "Canberra", "Ottawa", "Bangkok",2], 
  ["2. When was the Indian National Congress found?","1885","1800","1857","1915",1], 
  ["3. Who is the president of USA?",'Abraham Lincoln', 'Barak Obama', 'Rishi Sunak', "Joe Biden",4], 
  ['4. The international Literacy day is celebrated on-','Sept 8','Nov 28','May 2','Sept 22',1], 
  ["5. The language of Lakshadweep Islands is-","Tamil", "Hindi","Malayalam","Telugu",3], 
  ["6. Which day is observed as the World Standards Day?","June 26","Oct 14","Nov 15","Dec 2",2], 
  ["7. Which of these spices is the smallest in size?", "Ajwain", "Jeera", "Saunf", "Methi Seeds", 1], 
  
  ["8.On 30th May 2022, which European city's mayor flagged off a special tram, to celebrate Azadi ka Amrit Mahotsav?", 
"Poznan", "Wroclaw", "Warsaw","Paris",2],

  ["9.Which Indian author's mother was the first woman to become a Chief Justice of a state High Court?", 
"Amitav Ghosh", "Vikram Seth", "Samit Basu", "Ashok Banker", 2 ], 

  ["10.On which if these would you generally find designs of 'zari'?", "Bottles", "Car", "Clothes", "Books", 3], 

  ["11.Which of the following flowers is known as the 'Terror of Bengal'?",
"Water Hyacinth", "Rafflesia", "Babia", "Glory Lily",1 ], 

  [ "12. When was the Delhi Startup Policy launched?","2020","2016","2022","2021",3], 

  ["13.Pandit Shivkumar Sharma was an exponent of which of these musical instruments?", "Santoor", "Sitar", "Surbahar", 
"Mandolin", 1], 

  ["14.If the Akal Takht Express train starts in West Bengal, where does its journey end?", 
"Patna", "Amritsar", "Patiala", "Haryana", 2],

  ["15.Established in 2019 by the Ministry of Home Affairs, who is the National Unit Award named after?", 
"Sardar Vallabhai Patel", "Pandit Nehru", "Mahatma Gandhi", "Subhash Chandra Bose", 1 ], 
]

amount = [1000, 2000, 3000, 5000, 10000, 20000, 40000, 80000, '1,60,000', '3,20,000', '6,40,000', 
'12,50,000', '25,00,000', '50,00,000', '1 CRORE'] 

print("""Rules: \n \n1) There are 15 questions \n2) For each question you have 4 options out of which 1 is correct.
\n3) There are 3 checkpoints one at 5th question, one at 10th question 
and the last one at 15th question. 
\n4) If you want to quit the game in between you can quit by entering 0. The amount 
you earned till last question will be your winning amount."\n\n".""")


money=0 
for i in range(0, len(questions)): 
  ques= questions[i] 
  print("\n\n"+ques[0]) 
  print(f" 1.{ques[1]}", end="") 
  print(f"2. {ques[2]}".center(50)) 
  print(f" 3. {ques[3]}",end="") 
  print(f"4. {ques[4]}".center(50)) 

  reply= int(input("Enter the correct option number between (1-4): ")) 
  if (reply== 0): 
    money= amount[i-1]  
    break 
  elif (reply== ques[5]): 
    print(f"Congrats! You have won Rs. {amount[i]}") 
    
  else: 
    print("\n\nThe option chosen is wrong!!") 
    if (i>=4 and i<9):
      money= amount[4]
    elif(i>=9 and i<14):
      money= amount[9]
    else:
      money= amount[14]
    break 

print("Congratulations! You have won a total amount of Rs. ", money)
# Out:
#                         WELCOME TO KAUN BANEGA CROREPATI
# Rules:
#
# 1) There are 15 questions
# 2) For each question you have 4 options out of which 1 is correct.
#
# 3) There are 3 checkpoints one at 5th question, one at 10th question
# and the last one at 15th question.
#
# 4) If you want to quit the game in between you can quit by entering 0. The amount
# you earned till last question will be your winning amount."
#
# ".
#
#
# 1. What is the capital of Australia?
#  1.Sydney                   2. Canberra
#  3. Ottawa                    4. Bangkok
# Congrats! You have won Rs. 1000
#
#
# 2. When was the Indian National Congress found?
#  1.1885                     2. 1800
#  3. 1857                     4. 1915
# Congrats! You have won Rs. 2000
#
#
# 3. Who is the president of USA?
#  1.Abraham Lincoln                  2. Barak Obama
#  3. Rishi Sunak                   4. Joe Biden
# Congrats! You have won Rs. 3000
#
#
# 4. The international Literacy day is celebrated on-
# ...
